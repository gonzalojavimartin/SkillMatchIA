# %%
import pandas as pd

# %%
data = pd.read_csv('../static/datasets/2024.1_encuesta-sysarmy.csv')
# Seleccion de columnas relevantes y preprocesamiento
relevant_columns = [
    'plataformas_que_utilizas_en_tu_puesto_actual',
    'lenguajes_de_programacion_o_tecnologias_que_utilices_en_tu_puesto_actual',
    'frameworksherramientas_y_librerias_que_utilices_en_tu_puesto_actual',
    'bases_de_datos',
    'qa_testing'
]

filtered_data = data[relevant_columns].dropna()

columns_rename = {
    "plataformas_que_utilizas_en_tu_puesto_actual" : "plataformas",
    "lenguajes_de_programacion_o_tecnologias_que_utilices_en_tu_puesto_actual" : "lenguajes",
    "frameworksherramientas_y_librerias_que_utilices_en_tu_puesto_actual" : "frameworks",
    "bases_de_datos":"databases"
}

filtered_data.rename(columns=columns_rename, inplace=True)

# %%
from collections import Counter

relevant_columns = [
    "plataformas",
    "lenguajes",
    "frameworks",
    "databases",
    "qa_testing"
]

tech_terms = []

for col in relevant_columns:
    column_terms = filtered_data[col].str.split(',').explode().str.strip()
    column_terms = column_terms[~column_terms.isin(['.','-','','Ninguna de las anteriores','Ninguno de los anteriores'])]
    for term in column_terms:
        tech_terms.append(term)

technologies = pd.DataFrame({ "tech_terms" : tech_terms })
most_common_techs = Counter(tech_terms).most_common(150)
most_common_techs
# Out:
# [('SQL', 2795),
#  ('Linux', 2158),
#  ('Javascript', 2092),
#  ('Docker', 2036),
#  ('MySQL', 1728),
#  ('Amazon Web Services', 1674),
#  ('Python', 1649),
#  ('HTML', 1530),
#  ('Microsoft SQL Server', 1384),
#  ('PostgreSQL', 1322),
#  ('Azure', 1166),
#  ('Postman', 1166),
#  ('Windows Server', 1143),
#  ('Node.js', 1122),
#  ('TypeScript', 1106),
#  ('React.js', 1044),
#  ('CSS', 1015),
#  ('Java', 981),
#  ('Kubernetes', 948),
#  ('Bash/Shell', 903),
#  ('Google Cloud Platform', 896),
#  ('MongoDB', 854),
#  ('Bootstrap', 674),
#  ('.NET', 634),
#  ('VMWare', 628),
#  ('MariaDB', 622),
#  ('Oracle', 612),
#  ('PHP', 608),
#  ('.NET Core', 568),
#  ('Redis', 555),
#  ('Angular', 549),
#  ('Jest', 526),
#  ('C#', 522),
#  ('JUnit', 516),
#  ('jQuery', 513),
#  ('Spring', 508),
#  ('Next.js', 455),
#  ('Amazon DynamoDB', 437),
#  ('ElasticSearch', 435),
#  ('SAP', 409),
#  ('SQLite', 397),
#  ('Amazon RDS/Aurora', 394),
#  ('Serverless', 386),
#  ('Microsoft Azure (Tables', 380),
#  ('CosmosDB', 380),
#  ('etc)', 380),
#  ('Google Cloud Storage', 360),
#  ('Firebase', 342),
#  ('Go', 314),
#  ('Selenium', 301),
#  ('WordPress', 298),
#  ('Cypress', 278),
#  ('Django', 254),
#  ('OpenShift', 249),
#  ('Hibernate', 240),
#  ('Flask', 231),
#  ('Vue.js', 227),
#  ('Laravel', 226),
#  ('SoapUI', 207),
#  ('Cucumber', 168),
#  ('Amazon Redshift', 161),
#  ('Spark', 158),
#  ('Kotlin', 157),
#  ('Visual Studio Coded UI', 152),
#  ('PHPUnit', 142),
#  ('C++', 138),
#  ('VBA', 136),
#  ('TensorFlow', 108),
#  ('C', 107),
#  ('Microcontroladores', 101),
#  ('SAP Hana', 98),
#  ('IBM Db2', 93),
#  ('Xunit', 92),
#  ('Teradata', 91),
#  ('Cassandra', 91),
#  ('Mocha', 90),
#  ('R', 88),
#  ('HANA', 86),
#  ('Ruby', 84),
#  ('Flutter', 82),
#  ('Groovy', 79),
#  ('Mainframe', 78),
#  ('Hadoop', 76),
#  ('NUnit', 75),
#  ('Arduino o similar', 74),
#  ('OpenStack', 72),
#  ('Symfony', 69),
#  ('Rails', 67),
#  ('Appium', 61),
#  ('Arduino', 57),
#  ('Torch', 57),
#  ('IBM Cloud / Watson', 56),
#  ('Dart', 56),
#  ('Swift', 53),
#  ('Sybase', 53),
#  ('Scala', 51),
#  ('Cordova', 50),
#  ('Apache Hive', 50),
#  ('Perl', 48),
#  ('CodeIgniter', 48),
#  ('Puppeteer', 48),
#  ('AIX', 46),
#  ('COBOL', 45),
#  ('Rust', 44),
#  ('Informix', 44),
#  ('HTMX', 43),
#  ('ABAP', 42),
#  ('Solaris', 40),
#  ('TFS', 39),
#  ('Figma', 38),
#  ('Drupal', 38),
#  ('Karma', 38),
#  ('SwiftUI', 37),
#  ('RSpec', 36),
#  ('Playwright', 35),
#  ('Salesforce', 34),
#  ('*BSD', 31),
#  ('Solidity', 29),
#  ('FastAPI', 27),
#  ('Neo4j', 27),
#  ('Percona Server', 27),
#  ('HP-UX', 25),
#  ('Objective-C', 23),
#  ('pytest', 23),
#  ('Delphi', 22),
#  ('Katalon', 22),
#  ('Assembler', 21),
#  ('Test Complete', 21),
#  ('Amazon HBase', 20),
#  ('Ninguna', 19),
#  ('Akka', 19),
#  ('ProxySQL', 18),
#  ('Pytest', 17),
#  ('React Native', 16),
#  ('Powershell', 16),
#  ('Jira', 14),
#  ('Genexus', 14),
#  ('Apex', 14),
#  ('Elixir', 14),
#  ('Matlab', 14),
#  ('OpenQA', 14),
#  ('Databricks', 12),
#  ('Snowflake', 12),
#  ('Proxmox', 12),
#  ('Quarkus', 12),
#  ('Smalltalk', 11),
#  ('Bun', 11),
#  ('Vitest', 10),
#  ('GeneXus', 9),
#  ('Terraform', 9)]

# %%
aux = pd.DataFrame(most_common_techs)
techs_to_save = pd.DataFrame(aux[0])
techs_to_save.rename(columns={0 : 'tech_terms'}, inplace=True)
filepath = '../static/models/technologies.csv'
techs_to_save.to_csv(filepath, index=False)
